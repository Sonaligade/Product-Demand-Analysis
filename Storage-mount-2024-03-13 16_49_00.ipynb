# %%
configs = {
  "fs.azure.account.auth.type": "CustomAccessToken",
  "fs.azure.account.custom.token.provider.class": spark.conf.get("spark.databricks.passthrough.adls.gen2.tokenProviderClassName")
}

# Optionally, you can add <directory-name> to the source URI of your mount point.
dbutils.fs.mount(
  source = "abfss://bronze@salesanalyticsblob.dfs.core.windows.net/",
  mount_point = "/mnt/bronze",
  extra_configs = configs)
# Out:
# ---------------------------------------------------------------------------
# ExecutionError                            Traceback (most recent call last)
# File <command-3432783397685378>, line 7
#       1 configs = {
#       2   "fs.azure.account.auth.type": "CustomAccessToken",
#       3   "fs.azure.account.custom.token.provider.class": spark.conf.get("spark.databricks.passthrough.adls.gen2.tokenProviderClassName")
#       4 }
#       6 # Optionally, you can add <directory-name> to the source URI of your mount point.
# ----> 7 dbutils.fs.mount(
#       8   source = "abfss://bronze@salesanalyticsblob.dfs.core.windows.net/",
#       9   mount_point = "/mnt/bronze",
#      10   extra_configs = configs)
#
# File /databricks/python_shell/dbruntime/dbutils.py:362, in DBUtils.FSHandler.prettify_exception_message.<locals>.f_with_exception_handling(*args, **kwargs)
#     360 exc.__context__ = None
#     361 exc.__cause__ = None
# --> 362 raise exc
#
# ExecutionError: An error occurred while calling o408.mount.
# : java.rmi.RemoteException: java.lang.IllegalArgumentException: requirement failed: Directory already mounted: /mnt/bronze; nested exception is:
# 	java.lang.IllegalArgumentException: requirement failed: Directory already mounted: /mnt/bronze
# 	at com.databricks.backend.daemon.data.client.DbfsClient.send0(DbfsClient.scala:135)
# 	at com.databricks.backend.daemon.data.client.DbfsClient.sendIdempotent(DbfsClient.scala:69)
# 	at com.databricks.backend.daemon.dbutils.DBUtilsCore.createOrUpdateMount(DBUtilsCore.scala:1029)
# 	at com.databricks.backend.daemon.dbutils.DBUtilsCore.$anonfun$mount$1(DBUtilsCore.scala:1055)
# 	at com.databricks.logging.UsageLogging.$anonfun$recordOperation$1(UsageLogging.scala:571)
# 	at com.databricks.logging.UsageLogging.executeThunkAndCaptureResultTags$1(UsageLogging.scala:666)
# 	at com.databricks.logging.UsageLogging.$anonfun$recordOperationWithResultTags$4(UsageLogging.scala:684)
# 	at com.databricks.logging.UsageLogging.$anonfun$withAttributionContext$1(UsageLogging.scala:426)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:62)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:196)
# 	at com.databricks.logging.UsageLogging.withAttributionContext(UsageLogging.scala:424)
# 	at com.databricks.logging.UsageLogging.withAttributionContext$(UsageLogging.scala:418)
# 	at com.databricks.backend.daemon.dbutils.FSUtils.withAttributionContext(DBUtilsCore.scala:69)
# 	at com.databricks.logging.UsageLogging.withAttributionTags(UsageLogging.scala:470)
# 	at com.databricks.logging.UsageLogging.withAttributionTags$(UsageLogging.scala:455)
# 	at com.databricks.backend.daemon.dbutils.FSUtils.withAttributionTags(DBUtilsCore.scala:69)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags(UsageLogging.scala:661)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags$(UsageLogging.scala:580)
# 	at com.databricks.backend.daemon.dbutils.FSUtils.recordOperationWithResultT ... (truncated)

# %%
dbutils.fs.ls("/mnt/bronze")
# Out:
# [FileInfo(path='dbfs:/mnt/bronze/YTD 2018 _SWH.xlsx.csv', name='YTD 2018 _SWH.xlsx.csv', size=2080203, modificationTime=1710139690000),
#  FileInfo(path='dbfs:/mnt/bronze/YTD 2018 _SWH.xlsx.parquet', name='YTD 2018 _SWH.xlsx.parquet', size=299230, modificationTime=1710161669000),
#  FileInfo(path='dbfs:/mnt/bronze/datasheet_0.csv', name='datasheet_0.csv', size=1599840, modificationTime=1710326743000),
#  FileInfo(path='dbfs:/mnt/bronze/datasheet_1.csv', name='datasheet_1.csv', size=1149194, modificationTime=1710326769000),
#  FileInfo(path='dbfs:/mnt/bronze/datasheet_2.csv', name='datasheet_2.csv', size=1025816, modificationTime=1710326787000),
#  FileInfo(path='dbfs:/mnt/bronze/datasheet_3.csv', name='datasheet_3.csv', size=890699, modificationTime=1710326807000)]

# %%
dbutils.fs.mount(
  source = "abfss://silver@salesanalyticsblob.dfs.core.windows.net/",
  mount_point = "/mnt/silver",
  extra_configs = configs)

# %%
dbutils.fs.ls("/mnt/silver")
# Out:
# [FileInfo(path='dbfs:/mnt/silver/YTD 2018 _SWH.xlsx.parquet', name='YTD 2018 _SWH.xlsx.parquet', size=298178, modificationTime=1709201087000),
#  FileInfo(path='dbfs:/mnt/silver/_SUCCESS', name='_SUCCESS', size=0, modificationTime=1710161942000),
#  FileInfo(path='dbfs:/mnt/silver/part-00000-6e4dba07-40a1-40ec-95c7-00d1a59e67b6-c000.snappy.parquet', name='part-00000-6e4dba07-40a1-40ec-95c7-00d1a59e67b6-c000.snappy.parquet', size=166742, modificationTime=1710158719000),
#  FileInfo(path='dbfs:/mnt/silver/part-00000-ec7352d1-37c0-4d9c-b04b-8e38e6215ecb-c000.snappy.parquet', name='part-00000-ec7352d1-37c0-4d9c-b04b-8e38e6215ecb-c000.snappy.parquet', size=166742, modificationTime=1709555501000),
#  FileInfo(path='dbfs:/mnt/silver/part-00000-ef529865-d90d-4a9c-899c-282a05437ceb-c000.snappy.parquet', name='part-00000-ef529865-d90d-4a9c-899c-282a05437ceb-c000.snappy.parquet', size=166742, modificationTime=1710161942000),
#  FileInfo(path='dbfs:/mnt/silver/salesClean.parquet', name='salesClean.parquet', size=4787, modificationTime=1710142850000),
#  FileInfo(path='dbfs:/mnt/silver/salesClean2.csv', name='salesClean2.csv', size=1724448, modificationTime=1710146303000)]

# %%
dbutils.fs.mount(
  source = "abfss://gold@salesanalyticsblob.dfs.core.windows.net/",
  mount_point = "/mnt/gold",
  extra_configs = configs)

# %%
dbutils.fs.ls("/mnt/gold")
# Out:
# [FileInfo(path='dbfs:/mnt/gold/_committed_3665544642325878963', name='_committed_3665544642325878963', size=200, modificationTime=1709818605000),
#  FileInfo(path='dbfs:/mnt/gold/_committed_4799244672694713447', name='_committed_4799244672694713447', size=240, modificationTime=1709812373000),
#  FileInfo(path='dbfs:/mnt/gold/_committed_8147767470979488615', name='_committed_8147767470979488615', size=201, modificationTime=1709818775000),
#  FileInfo(path='dbfs:/mnt/gold/_started_3665544642325878963', name='_started_3665544642325878963', size=0, modificationTime=1709818604000),
#  FileInfo(path='dbfs:/mnt/gold/_started_8147767470979488615', name='_started_8147767470979488615', size=0, modificationTime=1709818774000),
#  FileInfo(path='dbfs:/mnt/gold/customerData/', name='customerData/', size=0, modificationTime=1709879420000),
#  FileInfo(path='dbfs:/mnt/gold/part-00000-tid-8147767470979488615-5780cf4e-f9d4-479a-b669-a6bd38e827d1-168-1-c000.csv', name='part-00000-tid-8147767470979488615-5780cf4e-f9d4-479a-b669-a6bd38e827d1-168-1-c000.csv', size=1269910, modificationTime=1709818775000),
#  FileInfo(path='dbfs:/mnt/gold/poData/', name='poData/', size=0, modificationTime=1709879422000),
#  FileInfo(path='dbfs:/mnt/gold/productData/', name='productData/', size=0, modificationTime=1709879421000),
#  FileInfo(path='dbfs:/mnt/gold/salesfactData/', name='salesfactData/', size=0, modificationTime=1709879424000),
#  FileInfo(path='dbfs:/mnt/gold/transportData/', name='transportData/', size=0, modificationTime=1709879422000)]
